# %% [raw]
# Datatrained
# Practice Project - 3
# Red Wine Quality Prediction
# Problem Statement:
# The dataset is related to red and white variants of the Portuguese "Vinho Verde" wine. Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).
#
# This dataset can be viewed as classification task. The classes are ordered and not balanced (e.g. there are many more normal wines than excellent or poor ones). Also, we are not sure if all input variables are relevant. So it could be interesting to test feature selection methods.
#
# Attribute Information
#
# Input variables (based on physicochemical tests):
# 1 - fixed acidity
# 2 - volatile acidity
# 3 - citric acid
# 4 - residual sugar
# 5 - chlorides
# 6 - free sulfur dioxide
# 7 - total sulfur dioxide
# 8 - density
# 9 - pH
# 10 - sulphates
# 11 - alcohol
# Output variable (based on sensory data):
# 12 - quality (score between 0 and 10)
#
# What might be an interesting thing to do, is to set an arbitrary cutoff for your dependent variable (wine quality) at e.g. 7 or higher getting classified as 'good/1' and the remainder as 'not good/0'.
# This allows you to practice with hyper parameter tuning on e.g. decision tree algorithms looking at the ROC curve and the AUC value.
#
# You need to build a classification model.
#
# Inspiration
#
# Use machine learning to determine which physiochemical properties make a wine 'good'!

# %%
import pandas as pd

# %%
df=pd.read_csv("winequality.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# # EDA

# %% [markdown]
# SCATTERPLOT:

# %%
import seaborn as sns
sns.scatterplot(x="volatile acidity",y="quality",data=df)

# %% [markdown]
# we can se that volatile acidity is equally distributed @6 in range 0.1 to 0.9

# %%
sns.scatterplot(x="fixed acidity",y="quality",data=df)

# %% [markdown]
# we can se that the fixed acidity @6 is equally distributed at range 2 to 14

# %%
sns.scatterplot(x="citric acid",y="quality",data=df)

# %% [markdown]
# we can se that citric acid is equally distributed @ at range 0 to 0.7

# %%
sns.scatterplot(x="residual sugar",y="quality",data=df)

# %% [markdown]
# we can se that residual sugar is equally distributed @6 is 1 to 5.5

# %%
sns.scatterplot(x="chlorides",y="quality",data=df)

# %% [markdown]
# we can se the chlorides is equally distributed at range is 0.03 to 0.3

# %%
sns.scatterplot(x="free sulfur dioxide",y="quality",data=df)

# %% [markdown]
# we can se that the free sulfur dioxide is equally distributed @6 in range 0 to 45

# %%
sns.scatterplot(x="total sulfur dioxide",y="quality",data=df)

# %% [markdown]
# we can se that the total sulfur dioxide is equally distributed @6 in range is 5 to 120

# %%
sns.scatterplot(x="density",y="quality",data=df)

# %% [markdown]
# we can se that the density is equally distributed @6 in range is 0.991 to 1.001

# %%
sns.scatterplot(x="pH",y="quality",data=df)

# %% [markdown]
# we can se that the ph is equally distributed in range @6 is 2.9 to 3.7

# %%
sns.scatterplot(x="sulphates",y="quality",data=df)

# %% [markdown]
# we can se that the sulphates is equally distributed @6 is range 0.40 to 1.15

# %%
sns.scatterplot(x="alcohol",y="quality",data=df)

# %% [markdown]
# we can se that the alchol is equally distributed at 6 in range of 9 to 13

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor='black',fmt='.2f')

# %% [markdown]
# # OUTCOME OF CORRELATION:

# %% [markdown]
# max corr is total sulfur dioxide
# min corr is chloride

# %% [markdown]
# # Describing Dataset:

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variable summary")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# # outlier checking:

# %%
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range (0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# residual sugar ,chloride and sulphate has more outliers

# %% [markdown]
# # Skewness:

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# outcome of skewness: the skewness threshold is taken has +/- 0.65, column which has  skewness is
#
#     fixed acidity
#     chlorides
#     total sulfur dioxide
#     sulphates

# %% [markdown]
# # Normal distribution Curve:

# %%
sns.distplot(df["fixed acidity"])

# %% [markdown]
# the data of the column is not normalised.the building blocks is out of the normalised curve

# %%
sns.distplot(df["chlorides"])

# %%
sns.distplot(df["volatile acidity"])

# %%
sns.distplot(df["citric acid"])

# %%
sns.distplot(df["residual sugar"])

# %%
sns.distplot(df["free sulfur dioxide"])

# %%
sns.distplot(df["density"])

# %%
sns.distplot(df["alcohol"])

# %%
sns.distplot(df["sulphates"])

# %%
sns.distplot(df["total sulfur dioxide"])

# %% [markdown]
# sns.distplot(df["pH"])

# %% [markdown]
# the data is not normalised,The building blocks is the out come of the normalised curve
#
# the normal distribution curve of outcome is irrelevant

# %% [markdown]
# # The normal distribution shows that data is irrelevant

# %% [markdown]
# data cleaning:

# %%
delete=pd.DataFrame([["0.06508","fixed acidity","NO","Alot"],["0.07472","chlorides","NO","Alot"]],columns=["correlation with Target","Columns NAme","Normalised","Outliers"])
delete
# Out:
#   correlation with Target   Columns NAme Normalised Outliers
# 0                 0.06508  fixed acidity         NO     Alot
# 1                 0.07472      chlorides         NO     Alot

# %%
df=df.drop(["fixed acidity","chlorides"],axis=1)

# %%
df
# Out:
#       volatile acidity  citric acid  residual sugar  free sulfur dioxide  \
# 0                0.700         0.00             1.9                 11.0
# 1                0.880         0.00             2.6                 25.0
# 2                0.760         0.04             2.3                 15.0
# 3                0.280         0.56             1.9                 17.0
# 4                0.700         0.00             1.9                 11.0
# ...                ...          ...             ...                  ...
# 1594             0.600         0.08             2.0                 32.0
# 1595             0.550         0.10             2.2                 39.0
# 1596             0.510         0.13             2.3                 29.0
# 1597             0.645         0.12             2.0                 32.0
# 1598             0.310         0.47             3.6                 18.0
#
#       total sulfur dioxide  density    pH  sulphates  alcohol  quality
# ...

# %% [markdown]
# # Removing outliers:

# %% [markdown]
# z-score technique:

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (1599, 10)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   33,   38,   43,   45,   57,   81,
#          86,   88,   91,   92,   95,  106,  109,  120,  126,  127,  142,
#         144,  151,  151,  151,  163,  164,  169,  199,  226,  258,  274,
#         324,  325,  339,  340,  354,  396,  396,  400,  400,  442,  459,
#         467,  480,  480,  494,  515,  517,  554,  555,  557,  584,  588,
#         591,  595,  608,  614,  636,  639,  649,  649,  651,  652,  652,
#         672,  672,  684,  690,  690,  692,  695,  723,  724,  795,  821,
#         832,  836,  837,  889,  899,  911,  917,  923,  925,  926,  982,
#        1017, 1018, 1043, 1051, 1071, 1074, 1079, 1079, 1081, 1081, 1111,
#        1114, 1131, 1154, 1175, 1186, 1231, 1235, 1244, 1244, 1244, 1269,
#        1269, 1270, 1270, 1288, 1289, 1295, 1296, 1299, 1299, 1300, 1312,
#        1316, 1319, 1321, 1358, 1367, 1370, 1372, 1374, 1434, 1434, 1434,
#        1435, 1435, 1435, 1469, 1474, 1474, 1474, 1476, 1476, 1476, 1478,
# ...

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (1599, 10)
# (1475, 10)

# %% [markdown]
# # Percentage of data loss:

# %%
loss_percent=(1599-1475)/1599*100
print(loss_percent)
# Out:
# 7.754846779237024

# %% [markdown]
# checking whether how much outliers are still there, if thee outliers there help in the testing the model or not
#
# dividing data in features and vectors:

# %%
x=df_new.iloc[:,:-1]
y=df_new.iloc[:,-1]

# %% [markdown]
# # Transform the data to remove skewness:

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 1.06147917, -1.53010481, -0.61099634, ...,  1.36720151,
#         -0.60258526, -1.10460933],
#        [ 1.92628712, -1.53010481,  0.65124716, ..., -0.78529789,
#          0.42289695, -0.51873366],
#        [ 1.36296139, -1.25413013,  0.20894852, ..., -0.3585312 ,
#          0.1956861 , -0.51873366],
#        ...,
#        [ 0.0033492 , -0.68067198,  0.20894852, ...,  0.75538633,
#          0.89122573,  0.74874474],
#        [ 0.77223156, -0.74141202, -0.37456717, ...,  1.76942106,
#          0.63356375, -0.02539596],
#        [-1.32422044,  1.04571482,  1.54768453, ...,  0.54912862,
#          0.27335849,  0.74874474]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.06147917, -1.53010481, -0.61099634, ...,  1.36720151,
#         -0.60258526, -1.10460933],
#        [ 1.92628712, -1.53010481,  0.65124716, ..., -0.78529789,
#          0.42289695, -0.51873366],
#        [ 1.36296139, -1.25413013,  0.20894852, ..., -0.3585312 ,
#          0.1956861 , -0.51873366],
#        ...,
#        [ 0.0033492 , -0.68067198,  0.20894852, ...,  0.75538633,
#          0.89122573,  0.74874474],
#        [ 0.77223156, -0.74141202, -0.37456717, ...,  1.76942106,
#          0.63356375, -0.02539596],
#        [-1.32422044,  1.04571482,  1.54768453, ...,  0.54912862,
#          0.27335849,  0.74874474]])

# %% [markdown]
# # since the outcome has only two variable we wil use binary classification model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Splitting the dataframe:

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print("at random state",i,"The Model Perform Very Well")
        print("at random_state:-",i)
        print("Training r2_score is:-",accuracy_score(y_train,pred_train)*100)
        print("Training r2_score is:-",accuracy_score(y_test,pred_test)*100)
# Out:
# at random state 254 The Model Perform Very Well
# at random_state:- 254
# Training r2_score is:- 60.25423728813559
# Training r2_score is:- 60.33898305084746
# at random state 299 The Model Perform Very Well
# at random_state:- 299
# Training r2_score is:- 60.67796610169491
# Training r2_score is:- 60.67796610169491
# at random state 306 The Model Perform Very Well
# at random_state:- 306
# Training r2_score is:- 60.33898305084746
# Training r2_score is:- 60.33898305084746
# at random state 380 The Model Perform Very Well
# at random_state:- 380
# Training r2_score is:- 61.35593220338983
# Training r2_score is:- 61.35593220338983
# at random state 661 The Model Perform Very Well
# at random_state:- 661
# Training r2_score is:- 61.35593220338983
# Training r2_score is:- 61.35593220338983
# at random state 729 The Model Perform Very Well
# at random_state:- 729
# Training r2_score is:- 61.440677966101696
# Training r2_score is:- 61.35593220338983
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=899)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00        10
#            5       0.39      0.42      0.41       118
#            6       0.35      0.44      0.39       121
#            7       0.00      0.00      0.00        42
#            8       0.00      0.00      0.00         4
#
#     accuracy                           0.35       295
#    macro avg       0.15      0.17      0.16       295
# weighted avg       0.30      0.35      0.32       295
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Cross validation score for logistic regression:

# %%
pred_lr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(y_test,pred_lr)
for j in range(2,10):
    lsscore=cross_val_score(lr,x,y,cv=j)
    lsc=lsscore.mean()
    print("At cv:-",j)
    print("Cross validation score is:-",lsc*100)
    print("accuracy_score is:-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# Cross validation score is:- 55.59388938529819
# accuracy_score is:- 59.66101694915255
#
#
# At cv:- 3
# Cross validation score is:- 57.830791648038684
# accuracy_score is:- 59.66101694915255
#
#
# At cv:- 4
# Cross validation score is:- 58.84901172381289
# accuracy_score is:- 59.66101694915255
#
#
# At cv:- 5
# Cross validation score is:- 58.10169491525424
# accuracy_score is:- 59.66101694915255
#
#
# At cv:- 6
# Cross validation score is:- 58.91737182677949
# accuracy_score is:- 59.66101694915255
#
#
# At cv:- 7
# Cross validation score is:- 58.850307895670106
# accuracy_score is:- 59.66101694915255
#
#
# At cv:- 8
# Cross validation score is:- 59.53326968272621
# accuracy_score is:- 59.66101694915255
#
#
# At cv:- 9
# Cross validation score is:- 58.57648760536686
# accuracy_score is:- 59.66101694915255

# %% [markdown]
# since cross validation score accuracy score are almost same.we are heading with a good approach

# %%
lsscore_selected=cross_val_score(lr,x,y,cv=4).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv score is:  0.5884901172381289
# The accuracy score is:  0.5966101694915255

# %% [markdown]
# # AUC ROC Curve:

# %%
from sklearn.metrics import roc_curve,auc
fpr,tpr,thresholds=roc_curve(pred_test,y_test)
roc_auc=auc(fpr,tpr)

plt.figure()
plt.plot(fpr,tpr,color='darkorange',lw=10,label='ROC curve (area=%0.2f)'% roc_auc)
plt.plot([0,1], [0,1],color='navy',lw=10, linestyle='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Model Saving:

# %%
import pickle
filename = 'winequality.pl'
pickle.dump(lr,open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(lr.predict(x_test))
df_com=pd.DataFrame({"original":a,"predicted":predicted},index=range(len(a)))
df_com
